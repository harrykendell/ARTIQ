# %%
from ndscan.results.tools import find_ndscan_roots
from oitg.results import load_hdf5_file
from ndscan.results.arguments import extract_param_schema

# ndscan_roots = find_ndscan_roots(
#   "/home/ae19663/artiq/results/2025-09-29/19/000012507-TrapFrequencyExpFrag.h5"
# )

file = load_hdf5_file(  # type: ignore
    "/home/ae19663/artiq/results/2025-09-29/19/000012507-TrapFrequencyExpFrag.h5"
)

a = extract_param_schema(  # type: ignore
    file["expid"]["arguments"]
)


find_ndscan_roots(file)
# Out:
# []
