# %%
#code to solve set of linear equation Ax=b using numpy
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import linregress
from scipy.signal import find_peaks
import pandas as pd
import math
from scipy.ndimage import gaussian_filter1d
from scipy.ndimage import gaussian_filter
from scipy.signal import savgol_filter
from scipy.stats import linregress
from scipy.optimize import curve_fit
from scipy import stats
from scipy.stats import chisquare       

a=200
c=170

#solve set of three nonlinear equations
def equations(vars):
    b, d = vars
    eq1 = a + b + d - 300
    eq2 = (b-90)**2-(d+c)**2 +a**2

    return [eq1, eq2]

b, y = 1, 1
solution = optimize.fsolve(equations, (b, y))
print(f"Solution: b={solution[0]}, d={solution[1]}")

print(solution[1]+c)
# Out:
# Solution: b=68.88888888888887, d=31.11111111111111
# 201.11111111111111
